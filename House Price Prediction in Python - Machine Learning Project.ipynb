# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data.dropna(inplace=True)

# %%
data.info
# Out:
# <bound method DataFrame.info of        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
from sklearn.model_selection import train_test_split

x=data.drop(['median_house_value'], axis=1)
y=data['median_house_value']

# %%
X
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-b5fec669aca1> in <module>
# ----> 1 X
#
# NameError: name 'X' is not defined

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
train_data =x_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3090     -118.41     35.63                15.0       5907.0          1257.0
# 5445     -118.44     34.00                22.0       5822.0          1707.0
# 3676     -118.39     34.21                14.0       2807.0           868.0
# 18991    -122.01     38.44                12.0       2344.0           354.0
# 12041    -117.49     33.90                 7.0      10235.0          2238.0
# ...          ...       ...                 ...          ...             ...
# 10558    -117.72     33.64                16.0       1230.0           242.0
# 5644     -118.29     33.75                27.0       1650.0           443.0
# 17476    -119.92     34.44                17.0       2143.0           324.0
# 8090     -118.21     33.81                40.0       1815.0           428.0
# 19668    -120.83     37.50                30.0       1340.0           244.0
#
# ...

# %%
train_data= train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'], axis=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3090     -118.41     35.63                15.0       5907.0          1257.0
# 5445     -118.44     34.00                22.0       5822.0          1707.0
# 3676     -118.39     34.21                14.0       2807.0           868.0
# 18991    -122.01     38.44                12.0       2344.0           354.0
# 12041    -117.49     33.90                 7.0      10235.0          2238.0
# ...          ...       ...                 ...          ...             ...
# 10558    -117.72     33.64                16.0       1230.0           242.0
# 5644     -118.29     33.75                27.0       1650.0           443.0
# 17476    -119.92     34.44                17.0       2143.0           324.0
# 8090     -118.21     33.81                40.0       1815.0           428.0
# 19668    -120.83     37.50                30.0       1340.0           244.0
#
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x="latitude", y="longitude", data=train_data, hue="median_house_value", palette="coolwarm")
# Out:
# <AxesSubplot:xlabel='latitude', ylabel='longitude'>

# %%
from sklearn.linear_model import LinearRegression

x_train, y_train =train_data.drop(['median_house_value'], axis=1), train_data['median_house_value']

reg= LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
test_data =x_test.join(y_test)

test_data['total_rooms']=np.log(test_data['total_rooms']+1)
test_data['total_bedrooms']=np.log(test_data['total_bedrooms']+1)
test_data['population']=np.log(test_data['population']+1)
test_data['households']=np.log(test_data['households']+1)

test_data=test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'], axis=1)

test_data['bedroom_ratio']=test_data['total_bedrooms']/test_data['total_rooms']
test_data['household_rooms']=test_data['total_rooms']/test_data['households']

# %%
x_test, y_test = test_data.drop(['median_house_value'], axis=1), test_data['median_house_value']

# %%
reg.score(x_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-8cab6433b12d> in <module>
# ----> 1 reg.score(x_test, y_test)
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     551
#     552         from .metrics import r2_score
# --> 553         y_pred = self.predict(X)
#     554         return r2_score(y, y_pred, sample_weight=sample_weight)
#     555
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     236             Returns predicted values.
#     237         """
# --> 238         return self._decision_function(X)
#     239
#     240     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     219
#     220         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
# ...

# %%
print("Columns in x_train:", x_train.columns)
print("Columns in x_test:", x_test.columns)
# Out:
# Columns in x_train: Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        '<1H OCEAN', 'INLAND', 'ISLAND', 'NEAR BAY', 'NEAR OCEAN'],
#       dtype='object')
# Columns in x_test: Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        '<1H OCEAN', 'INLAND', 'ISLAND', 'NEAR BAY', 'NEAR OCEAN',
#        'bedroom_ratio', 'household_rooms'],
#       dtype='object')

# %%
x_test = x_test[['longitude', 'latitude', 'housing_median_age', 'total_rooms',
                 'total_bedrooms', 'population', 'households', 'median_income',
                 '<1H OCEAN', 'INLAND', 'ISLAND', 'NEAR BAY', 'NEAR OCEAN']]

# %%
reg.score(x_test, y_test)
# Out:
# 0.5867435199041768

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
train_data['bedroom_ratio']=train_data['total_bedrooms']/train_data['total_rooms']
train_data['household_rooms']=train_data['total_rooms']/train_data['households']

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
from sklearn.linear_model import LinearRegression

x_train, y_train = train_data.drop(['median_house_value'], axis=1), train_data['median_house_value']

reg= LinearRegression()

reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
test_data = x_test.join(y_test)

test_data['total_rooms'] = np.log(test_data['total_rooms'] + 1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] + 1)
test_data['population'] = np.log(test_data['population'] + 1)
test_data['households'] = np.log(test_data['households'] + 1)

# Check if 'ocean_proximity' column exists before applying get_dummies
if 'ocean_proximity' in test_data.columns:
    test_data = test_data.join(pd.get_dummies(test_data['ocean_proximity'])).drop(['ocean_proximity'], axis=1)

test_data['bedroom_ratio'] = test_data['total_bedrooms'] / test_data['total_rooms']
test_data['household_rooms'] = test_data['total_rooms'] / test_data['households']

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 8866     -118.39     34.06                39.0     2.208459        2.044311
# 11729    -120.01     39.26                26.0     2.147777        1.941796
# 14857    -117.08     32.64                43.0     2.068600        1.862904
# 7315     -118.19     33.97                34.0     2.186206        2.033210
# 18757    -122.38     40.67                10.0     2.167087        1.959824
# ...          ...       ...                 ...          ...             ...
# 4913     -118.27     34.01                43.0     2.094285        1.939581
# 18251    -122.10     37.39                31.0     2.081851        1.905135
# 15000    -117.04     32.74                33.0     2.226120        2.034403
# 11168    -117.99     33.82                33.0     2.170103        1.969266
# 7374     -118.22     33.97                47.0     2.132021        1.939953
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-8cab6433b12d> in <module>
# ----> 1 reg.score(x_test, y_test)
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     551
#     552         from .metrics import r2_score
# --> 553         y_pred = self.predict(X)
#     554         return r2_score(y, y_pred, sample_weight=sample_weight)
#     555
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     236             Returns predicted values.
#     237         """
# --> 238         return self._decision_function(X)
#     239
#     240     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     219
#     220         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
# ...

# %%
x_train, y_train = train_data.drop(['median_house_value'], axis=1), train_data['median_house_value']

# %%
reg.score(x_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-8cab6433b12d> in <module>
# ----> 1 reg.score(x_test, y_test)
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     551
#     552         from .metrics import r2_score
# --> 553         y_pred = self.predict(X)
#     554         return r2_score(y, y_pred, sample_weight=sample_weight)
#     555
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     236             Returns predicted values.
#     237         """
# --> 238         return self._decision_function(X)
#     239
#     240     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     219
#     220         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
# ...

# %%
# Assuming reg is your linear regression model
# Assuming x_train and y_train were used during training

# Ensure x_test has the same features as x_train
# Adjust x_test columns as needed
adjusted_x_test = x_test[x_train.columns]

# Now, you can use reg.score with adjusted_x_test and y_test
score = reg.score(adjusted_x_test, y_test)
print("R-squared score on the test set:", score)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-3a8fffe223db> in <module>
#       4 # Ensure x_test has the same features as x_train
#       5 # Adjust x_test columns as needed
# ----> 6 adjusted_x_test = x_test[x_train.columns]
#       7
#       8 # Now, you can use reg.score with adjusted_x_test and y_test
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# ...

# %%
# Assuming reg is your linear regression model
# Assuming x_train and y_train were used during training

# Apply the same transformations to the test set
x_test['total_rooms'] = np.log(x_test['total_rooms'] + 1)
x_test['total_bedrooms'] = np.log(x_test['total_bedrooms'] + 1)
x_test['population'] = np.log(x_test['population'] + 1)
x_test['households'] = np.log(x_test['households'] + 1)

# Create 'bedroom_ratio' and 'household_rooms' in the test set
x_test['bedroom_ratio'] = x_test['total_bedrooms'] / x_test['total_rooms']
x_test['household_rooms'] = x_test['total_rooms'] / x_test['households']

# Ensure x_test has the same features as x_train
# Adjust x_test columns as needed
adjusted_x_test = x_test[x_train.columns]

# Now, you can use reg.score with adjusted_x_test and y_test
score = reg.score(adjusted_x_test, y_test)
print("R-squared score on the test set:", score)
# Out:
# R-squared score on the test set: -1.3912674545582067
# <ipython-input-33-49681dba2b4f>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_test['total_rooms'] = np.log(x_test['total_rooms'] + 1)
# <ipython-input-33-49681dba2b4f>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_test['total_bedrooms'] = np.log(x_test['total_bedrooms'] + 1)
# <ipython-input-33-49681dba2b4f>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# Assuming reg is your linear regression model
# Assuming x_train and y_train were used during training

# Apply the same transformations to the test set using .loc
x_test.loc[:, 'total_rooms'] = np.log(x_test['total_rooms'] + 1)
x_test.loc[:, 'total_bedrooms'] = np.log(x_test['total_bedrooms'] + 1)
x_test.loc[:, 'population'] = np.log(x_test['population'] + 1)
x_test.loc[:, 'households'] = np.log(x_test['households'] + 1)

# Create 'bedroom_ratio' and 'household_rooms' in the test set using .loc
x_test.loc[:, 'bedroom_ratio'] = x_test['total_bedrooms'] / x_test['total_rooms']
x_test.loc[:, 'household_rooms'] = x_test['total_rooms'] / x_test['households']

# Ensure x_test has the same features as x_train
# Adjust x_test columns as needed
adjusted_x_test = x_test[x_train.columns]

# Now, you can use reg.score with adjusted_x_test and y_test
score = reg.score(adjusted_x_test, y_test)
print("R-squared score on the test set:", score)
# Out:
# R-squared score on the test set: -1.629588719175934

# %%
# Assuming reg is your linear regression model
y_pred = reg.predict(adjusted_x_test)

# Calculate residuals
residuals = y_test - y_pred

# Plot residuals to identify patterns
import matplotlib.pyplot as plt

plt.scatter(y_test, residuals)
plt.title('Residuals Plot')
plt.xlabel('Actual Values')
plt.ylabel('Residuals')
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test, y_test)
# Out:
# 0.2988941224100643

# %%
# Assuming 'forest' is your trained RandomForestRegressor
feature_importances = forest.feature_importances_
feature_names = x_train.columns

# Sort feature importances in descending order
sorted_indices = np.argsort(feature_importances)[::-1]

# Plotting the feature importances
plt.figure(figsize=(10, 6))
plt.bar(range(len(feature_importances)), feature_importances[sorted_indices], align='center')
plt.xticks(range(len(feature_importances)), feature_names[sorted_indices], rotation=90)
plt.xlabel('Feature')
plt.ylabel('Importance')
plt.title('Feature Importance in RandomForestRegressor')
plt.show()

# %%
from sklearn.model_selection import cross_val_score

# Assuming 'forest' is your trained RandomForestRegressor
cv_scores = cross_val_score(forest, x_train, y_train, cv=5)
print("Cross-Validation Scores:", cv_scores)
print("Mean R-squared score:", np.mean(cv_scores))
# Out:
# Cross-Validation Scores: [0.8093823  0.81284928 0.81188539 0.80131648 0.81858282]
# Mean R-squared score: 0.8108032516970883

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    "n_estimators":[3, 10, 30],
    "max_features":[2, 4, 6, 8]
    
}

grid_search =GridSearchCV(forest, param_grid, cv=5,
                         scoring="neg_mean_squared_error",
                         return_train_score=True)

grid_search.fit(x_train_s, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-f743e99fe194> in <module>
#      11                          return_train_score=True)
#      12
# ---> 13 grid_search.fit(x_train_s, y_train)
#
# NameError: name 'x_train_s' is not defined

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# Create a RandomForestRegressor instance
forest = RandomForestRegressor()

# Define the parameter grid
param_grid = {
    "n_estimators": [3, 10, 30],
    "max_features": [2, 4, 6, 8]
}

# Create a GridSearchCV object
grid_search = GridSearchCV(forest, param_grid, cv=5,
                           scoring="neg_mean_squared_error",
                           return_train_score=True)

# Assuming x_train is your training feature set and y_train is your target variable
grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': [2, 4, 6, 8],
#                          'n_estimators': [3, 10, 30]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
best_forest= grid_search.best_estimator_

# %%
best_forest.score(x_test_s, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-5794c1f3fa57> in <module>
# ----> 1 best_forest.score(x_test_s, y_test)
#
# NameError: name 'x_test_s' is not defined

# %%
# Assuming best_forest is your best RandomForestRegressor model
best_forest.score(x_test, y_test)
# Out:
# 0.37953137507203594
